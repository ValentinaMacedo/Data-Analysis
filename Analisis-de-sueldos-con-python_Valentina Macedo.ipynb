# %% [markdown]
# # Análisis de sueldos con Python

# %% [markdown]
# ## Data
#
# * [2021.2 - sysarmy - Encuesta de remuneración salarial Argentina
# ](https://docs.google.com/spreadsheets/d/1-ZRznwS4TK74o90aOiCKS5SiXxUQ2buN1wxZIMHQmzQ/edit#gid=557755710)
# * [2021.2 - sysarmy - Encuesta de remuneración salarial Latam
# ](https://docs.google.com/spreadsheets/d/1BkBNt1MHVS7DeIlpgmK9l6krtSQ5t_olRhlcyxMeKy0/edit#gid=557755710)

# %% [markdown]
# 1. Descargar, leer y unir en una sola estructura de datos. ¿Qué estructura elegiste y por qué?

# %%
import csv

dolar_conversion = (
  ('Argentina', 130.9),
  ('Bolivia', 6.86),
  ('Chile', 920.5773255),
  ('Colombia', 4445.01),
  ('Cuba', 24),
  ('Costa Rica', 671.4261825),
  ('Ecuador', 1),
  ('El Salvador', 8.75),
  ('Guatemala', 7.745829),
  ('Honduras', 24.6341828),
  ('México', 20.433),
  ('Nicaragua', 35.85),
  ('Panamá', 1),
  ('Paraguay', 6919.66395),
  ('Perú', 3.940374),
  ('Puerto Rico', 1),
  ('República Dominicana', 54.3192),
  ('Uruguay', 41.6290475),
  ('Venezuela', 5.7456)
)

# %%
import csv

dict_base = {}
list_base = []

list_data = []
with open('2021.2 - sysarmy - Encuesta de remuneración salarial Argentina - Argentina.csv', encoding='utf-8') as data_argentina:
    reader = csv.reader(data_argentina)
    for i, row in enumerate(reader):
        if i > 9:
        #if 9 < i < 500:
            list_data.append(["Argentina", *row])
                                        
paises = {
    "Bolivia": 1,
    "Chile": 2,
    "Colombia": 3,
    "Costa Rica": 4,
    "Cuba": 5,
    "Ecuador": 6,
    "El Salvador": 7,
    "Guatemala": 8,
    "Honduras": 9,
    "México": 10,
    "Nicaragua": 11,
    "Panamá": 12,
    "Paraguay": 13,
    "Perú": 14,
    "Puerto Rico": 15,
    "República Dominicana": 16,
    "Uruguay": 17,
    "Venezuela": 18
}

with open('2021.2 - sysarmy - Encuesta de remuneración salarial Latam - Latam.csv', encoding='utf-8') as data_latam:
    reader = csv.reader(data_latam)
    for i, row in enumerate(reader):
        #if 10 < i < 501:
        if i > 10:
            list_data.append([row[0], row[paises[row[0]]], *row[19:]])

            
preguntas = {
    "Pais": 0,
    "Region": 1, 
    "Tipo de contrato": 2,
    "Salario mensual o retiro BRUTO (en tu moneda local)": 3,
    "Salario mensual o retiro NETO (en tu moneda local)": 4,
    "Pagos en dólares": 5,
    "¿Cuál fue el último valor de dólar que tomaron?": 6,
    "¿Qué tan conforme estás con tu sueldo?": 7,
    "Cómo creés que está tu sueldo con respecto al último semestre": 8,
    "Recibís algún tipo de bono": 9,
    "A qué está atado el bono": 10,
    "¿Tuviste ajustes por inflación durante 202?": 11,
    "¿De qué % fue el ajuste total?": 12,
    "¿En qué mes fue el último ajuste?": 13,
    "Trabajo de": 14,
    "Años de experiencia": 15,
    "Años en la empresa actual": 16,
    "Años en el puesto actual": 17,
    "¿Gente a cargo?": 18,
    "Plataformas": 19,
    "Lenguajes de programación o tecnologías.": 20,
    "Frameworks, herramientas y librerías": 21,
    "Bases de datos": 22,
    "QA / Testing": 23,
    "IDEs": 24,
    "Cantidad de personas en tu organización": 25,
    "Trabajo para una empresa que no tiene oficina en mi ciudad": 26,
    "Actividad principal": 27,
    "¿La recomendás como un buen lugar para trabajar?": 28,
    "¿Cómo calificás las políticas de diversidad e inclusión?": 29,
    "Beneficios extra": 30,
    "¿Salir o seguir contestando?": 31,
    "Nivel de estudios alcanzado": 32,
    "Estado": 33,
    "Carrera": 34,
    "Universidad": 35,
    "Realizaste cursos de especialización": 36,
    "¿Contribuís a proyectos open source?": 37,
    "¿Programás como hobbie?": 38,
    "¿Salir o seguir contestando?": 39,
    "¿Tenés guardias?": 40,
    "Cuánto cobrás por guardia": 41,
    "¿Porcentaje, bruto o neto?": 42,
    "¿Salir o seguir contestando?": 43,
    "¿Sufriste o presenciaste situaciones de violencia laboral?": 44,
    "¿Tenés algún tipo de discapacidad?": 45,
    "¿Sentís que esto te dificultó el conseguir trabajo?": 46,
    "¿Salir o seguir contestando?": 47,
    "¿Cómo venís llevando la pandemia?": 48,
    "¿Tenés hijos/as menores de edad?": 49,
    "¿Con cuántas personas estás conviviendo?": 50,
    "¿Con quiénes convivís?": 51,
    "¿Tenés un espacio dedicado para el trabajo?": 52,
    "¿Tenés que compartir tu equipo de trabajo con alguien?": 53,
    "¿Qué tipo de cuarentena hiciste / estás haciendo?": 54,
    "¿Cambió tu situación laboral a raíz de la pandemia?": 55,
    "¿Qué tanto sentís que te está apoyando tu empresa/organización en esta situación?": 56,
    "¿Cómo se vio afectada tu empresa/organización?": 57,
    "¿Instauraron algún beneficio nuevo?": 58,
    "Tengo": 59,
    "Me identifico": 60,
}

#Para testear
#print(list_data[11][preguntas["Pais"]])
#print(list_data[11][preguntas["Salario mensual o retiro NETO (en tu moneda local)"]])
#print(list_data[11][preguntas["Trabajo de"]])


#Elegí trabajar con una lista de listas para luego poder unir mediante el método append la lista de Latam con la de Argentina
#Por otra parte cree un diccionario donde las keys corresponden a cada pregunta y los values su index correspondiente a la columna
#Esto último me va a facilitar acceder a los valores de la columna que necesite analizar
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [1], in <cell line: 7>()
#       4 list_base = []
#       6 list_data = []
# ----> 7 with open('2021.2 - sysarmy - Encuesta de remuneración salarial Argentina - Argentina.csv', encoding='utf-8') as data_argentina:
#       8     reader = csv.reader(data_argentina)
#       9     for i, row in enumerate(reader):
#
# FileNotFoundError: [Errno 2] No such file or directory: '2021.2 - sysarmy - Encuesta de remuneración salarial Argentina - Argentina.csv'

# %% [markdown]
# 2. Printear porcentaje de participación por región, ordenado de mayor a menor. Ej:
#
# ```
# - Ciudad Autónoma de Buenos Aires - 59.4%
# - Formosa - 0.04%
# ```

# %%
dic_regions={}

for row in list_data:
    region = row[preguntas["Region"]].upper()
    if region in dic_regions: 
        dic_regions[region] += ((1 / len(list_data)) * 100)
    else:     
        dic_regions[region] = ((1 / len(list_data)) * 100)

sorted_dic_regions = dict(sorted(dic_regions.items(), key=lambda item: item[1], reverse=True))
                              
for key in sorted_dic_regions:
    if key != ''and sorted_dic_regions[key]!= 0:
        print(f" - {key} {round(sorted_dic_regions[key],2)}%")
# Out:
#  - CIUDAD AUTÓNOMA DE BUENOS AIRES 51.71%
#  - PROVINCIA DE BUENOS AIRES 10.1%
#  - GBA 9.2%
#  - CÓRDOBA 7.8%
#  - SANTA FE 5.82%
#  - MENDOZA 2.18%
#  - MONTEVIDEO 1.7%
#  - ENTRE RÍOS 0.96%
#  - RÍO NEGRO 0.76%
#  - TUCUMÁN 0.76%
#  - NEUQUÉN 0.68%
#  - MISIONES 0.61%
#  - SANTIAGO 0.58%
#  - CHACO 0.57%
#  - MÉXICO DF 0.47%
#  - LIMA 0.45%
#  - SALTA 0.42%
#  - CORRIENTES 0.35%
#  - SAN JUAN 0.35%
#  - CHUBUT 0.28%
#  - JUJUY 0.28%
#  - BOGOTÁ 0.28%
#  - MEDELLÍN 0.25%
#  - LA RIOJA 0.23%
#  - QUITO 0.23%
#  - SAN LUIS 0.17%
#  - TIERRA DEL FUEGO 0.17%
#  - SANTIAGO DE CALI 0.13%
#  - LA PAMPA 0.12%
#  - SANTIAGO DEL ESTERO 0.12%
#  - CIUDAD GUATEMALA 0.12%
#  - GUADALAJARA 0.1%
#  - GUAYAQUIL 0.09%
#  - ASUNCIÓN 0.09%
#  - SANTA CRUZ 0.07%
#  - SANTA CRUZ DE LA SIERRA 0.07%
#  - CARACAS 0.07%
#  - QUERÉTARO 0.06%
#  - CATAMARCA 0.04%
#  - COCHABAMBA 0.04%
#  - VALPARAÍSO 0.04%
#  - TUNJA 0.04%
#  - MANIZALES 0.04%
#  - SAN JOSÉ 0.04%
#  - LOJA 0.04%
#  - MONTERREY 0.04%
#  - VERACRUZ 0.04%
#  - PUEBLA DE ZARAGOZA 0.04%
#  - VALENCIA 0.04%
#  - LA PAZ 0.03%
#  - PEREIRA 0.03%
#  - HEREDIA 0.03%
#  - CUENCA 0.03%
#  - PACHUCA 0.03%
#  - OAXACA DE JUÁREZ 0.03%
#  - VILLAHERMOSA 0.03%
#  - MÉRIDA 0.03%
#  - MORELIA 0.03%
#  - CULIACÁN 0.03%
#  - ZAPOPAN 0.03%
#  - MANAGUA 0.03%
#  - AREQUIPA 0.03%
#  - MALDONADO 0.03%
#  - SALTO 0.03%
#  - BARQUISIMETO 0.03%
#  - SAN CRISTÓBAL 0.03%
#  - FORMOSA 0.01%
#  - MAIPO 0.01%
#  - BIOBÍO 0.01%
#  - CACHAPOAL 0.01%
#  - TALCA 0.01%
#  - VALDIVIA 0.01%
#  - CÚCUTA 0.01%
#  - IBAGUÉ 0.01%
#  - CARTAGENA DE INDIAS 0.01%
#  - BUCARAMANGA 0.01%
#  - NEIVA 0.01%
#  - MONTERÍA 0.01%
#  - ARAUCA 0.01%
#  - PURRAL 0.01%
#  - PROVINCIA DE CIUDAD DE LA HABANA 0.01%
#  - SANCTI SPÍRITUS 0.01%
#  - SALINAS 0.01%
#  - AMBATO 0.01%
#  - RIOBAMBA 0.01%
#  - SANTA TECLA 0.01%
#  - SAN SALVADOR 0.01%
#  - ANTIGUA GUATEMALA 0.01%
#  - CUERNAVACA 0.01%
#  - SALTILLO 0.01%
#  - CHIHUAHUA 0.01%
#  - ECATEPEC 0.01%
#  - VICTORIA DE DURANGO 0.01%
#  - TIJUANA 0.01%
#  - CANCÚN 0.01%
#  - CIUDAD NEZAHUALCÓYOTL 0.01%
#  - CHINANDEGA 0.01%
#  - CIUDAD DE PANAMÁ 0.01%
#  - SAN LORENZO 0.01%
#  - ENCARNACIÓN 0.01%
#  - TRUJILLO 0.01%
#  - PUNO 0.01%
#  - SANTO DOMINGO 0.01%
#  - TRINIDAD 0.01%
#  - FLORIDA 0.01%
#  - BARCELONA 0.01%

# %% [markdown]
# 3. Printear porcentaje de participación por tipo de rol, ordenado de mayor a menor. Ej:
# `- Developer - 39.11 %`

# %%
dic_roles={}

for row in list_data:
    role = row[preguntas["Trabajo de"]].upper()
    if role in dic_roles: 
        dic_roles[role] += ((1 / len(list_data)) * 100)
    else:     
        dic_roles[role] = ((1 / len(list_data)) * 100)

sorted_dic_roles = dict(sorted(dic_roles.items(), key=lambda item: item[1], reverse=True))
                              
for key in sorted_dic_roles:
    if key != ''and sorted_dic_roles[key]!= 0:
        print(f" - {key} {round(sorted_dic_roles[key],2)}%")
# Out:
#  - DEVELOPER 40.69%
#  - SYSADMIN / DEVOPS / SRE 11.09%
#  - TECHNICAL LEADER 6.16%
#  - QA / TESTER 4.29%
#  - MANAGER / DIRECTOR 4.28%
#  - PROJECT MANAGER 3.09%
#  - HELPDESK 2.62%
#  - BI ANALYST / DATA ANALYST 2.45%
#  - ARCHITECT 2.23%
#  - CONSULTANT 1.92%
#  - DATA ENGINEER 1.76%
#  - BUSINESS ANALYST 1.69%
#  - NETWORKING 1.54%
#  - UX 1.5%
#  - DATA SCIENTIST 1.48%
#  - INFOSEC 1.43%
#  - RECRUITER / HR 1.24%
#  - PRODUCT MANAGER 1.21%
#  - DBA 0.71%
#  - SCRUM MASTER 0.66%
#  - DESIGNER 0.64%
#  - VP / C-LEVEL 0.55%
#  - SALES / PRE-SALES 0.42%
#  - FINANCE 0.17%
#  - ANALISTA FUNCIONAL 0.17%
#  - MIDDLEWARE 0.17%
#  - TECHNICAL WRITER 0.16%
#  - STORAGE / BACKUP 0.12%
#  - PRODUCT OWNER 0.09%
#  - TEAM LEADER 0.07%
#  - DOCENTE 0.07%
#  - SOFTWARE ENGINEER 0.06%
#  - FUNCTIONAL ANALYST 0.06%
#  - AGILE COACH 0.06%
#  - DEVOPS 0.06%
#  - SOPORTE 0.04%
#  - ANALISTA 0.04%
#  - SOPORTE TECNICO 0.04%
#  - CYBERSECURITY 0.04%
#  - COORDINADOR 0.04%
#  - RPA 0.04%
#  - SUPPORT ENGINEER 0.03%
#  - PEOPLE ANALYTICS 0.03%
#  - DATA ARCHITECT 0.03%
#  - PRODUCTOR Y VENDEDOR 0.03%
#  - CLOUD SECURITY 0.03%
#  - NLP DEVELOPER 0.03%
#  - SDET 0.03%
#  - PROFESOR 0.03%
#  - FRONTEND DEVELOPER 0.03%
#  - JEFE DE SISTEMAS 0.03%
#  - TECHNICAL ANALYST 0.03%
#  - SERVICE DESIGNER 0.03%
#  - PROJECT ENGINEERING 0.03%
#  - AUDITOR 0.03%
#  - QA AUTOMATION 0.03%
#  - QA LEAD 0.03%
#  - CLOUD ADMIN 0.03%
#  - UI 0.03%
#  - SOPORTE IT 0.03%
#  - CLOUD ENGINEER 0.03%
#  - ADMINISTRATIVO 0.03%
#  - SOPORTE TÉCNICO 0.03%
#  - CHANGE MANAGER 0.03%
#  - RPA DEVELOPER 0.03%
#  - OPERADOR NOC 0.03%
#  - IMPLEMENTADOR DE SISTEMAS 0.03%
#  - TECHNICAL BUSINESS ANALYST 0.01%
#  - ADMINISTRADOR INFRAESTRUCTURA 0.01%
#  - HELP DESK + BACKUP + VMWARE + SYS ADMIN 0.01%
#  - DATA VISUALIZATION 0.01%
#  - MAINFRAME 0.01%
#  - MACHINE LEARNING EGINEER 0.01%
#  - EXPLOIT WRITER 0.01%
#  - BI SR. MANAGER 0.01%
#  - OPERADOR 0.01%
#  - SOPORTE NIVEL 1,2 Y 3 0.01%
#  -  CLOUD ARCHITECT 0.01%
#  - ENGINEERING MANAGER 0.01%
#  - TÉCNICAMENTE SOY QA PERO HAGO TRABAJO DE PO ¿TRAINEE? 0.01%
#  - SRE 0.01%
#  - SUPERVISOR HELPDEK 0.01%
#  - ASISTENCIA TÉCNICA 0.01%
#  - LEAD 0.01%
#  - TECH SUPPORT  0.01%
#  - BACK OFFICE 0.01%
#  - JEFE OPERACION TI 0.01%
#  - AUDITORÍA 0.01%
#  - IT INFRASTRUCTURE ENGINEER 0.01%
#  - DATA CENTER 0.01%
#  - SOFTWARE ENGINEER  0.01%
#  - INFORMATION SECURITY 0.01%
#  - SAP BASIS 0.01%
#  - SEGURIDAD INFORMÁTICA  0.01%
#  - SEGURIDAD 0.01%
#  - COORDINADOR OPERACIONES Y SOPORTE APLICATIVO 0.01%
#  - APPLICATION ENGINEER 0.01%
#  - BECARIO DOCTORAL  0.01%
#  - AUTOMATION ENGINEER 0.01%
#  - ANALISTA TECNICO 0.01%
#  - IT AUDITOR 0.01%
#  - SECURITY ARCHITECT 0.01%
#  - IMPLEMENTACION DE SISTEMAS INFORMATICO DE SALUD -SAP -FUNCIONAL 0.01%
#  - GERENTE DE SISTEMAS 0.01%
#  - SOPORTE  TÉCNICO NIVEL 3 (INFRAESTRUCTURA) 0.01%
#  - SEGURIDAD INFORMATICA 0.01%
#  - COMUNICACIÓN / REDES SOCIALES 0.01%
#  - ADM DE INFRA 0.01%
#  - DEVELOPER, DEVOPS 0.01%
#  - ANALISTA SAP BASIS 0.01%
#  - SOPORTE TECNICO SQL 0.01%
#  - QA AUTOMATION  0.01%
#  - AV TECHNICAL SUPPORT 0.01%
#  - SALES EXECUTIVE 0.01%
#  - ETL DEVELOPER 0.01%
#  - SECURITY RESEARCHER 0.01%
#  - GERENTE DE ATRACCIÓN DE TI Y COMERCIAL 0.01%
#  - CYBERSECURITY  0.01%
#  - DELIVERY MANAGER 0.01%
#  - VARIOS 0.01%
#  - INTEGRATION  0.01%
#  - PROBLEM MANAGER 0.01%
#  - SOPORTE IT LAB NIVEL 1, 2, 3  0.01%
#  - DIRECTOR OF DEVOPS AND IT 0.01%
#  - PROYECT LEADER / DEVELOPER / TOOLSMITH 0.01%
#  - TECHNICAL OWNER 0.01%
#  - DATASTEWARD 0.01%
#  - SEGURIDAD INFORMÁTICA - ACCESOS 0.01%
#  - IPM 0.01%
#  - ESP. TELECOMUNICACIONES 0.01%
#  - QA - AUTOMATION ENGINEER 0.01%
#  - AD TECH 0.01%
#  - TRAINEE ETL 0.01%
#  - DATA GOVERNANCE SPECIALIST 0.01%
#  - JEFE DE CANALES DIGITALES 0.01%
#  - INGENIERO EN SEGURIDAD INFORMATICA 0.01%
#  - INCIDENT&RISK LEADER 0.01%
#  - MACHINE LEARNING ENGINEER 0.01%
#  - DEVELOPER/DEVOPS 0.01%
#  - UX USER RESEARCH 0.01%
#  - UX LEADER 0.01%
#  - IT OPERATIONS ANALYST 0.01%
#  - CUSTOMER SUCCESS MANAGER 0.01%
#  - MARKETING 0.01%
#  - ANALISTA MAINFRAME 0.01%
#  - APPLICATION DBA 0.01%
#  - NETWORK ANALYST SECURITY 0.01%
#  - UXUI 0.01%
#  - TECH LEAD / ARQUITECTO 0.01%
#  - CONSULTOR SENIOR - ESPECIALISTA EN CIBERSEGURIDAD 0.01%
#  - SERVICE DELIVERY MANAGER, APPLICATION SUPPORT, ITGC 0.01%
#  - ADMINISTRADOR DE WINDOWS SERVER - CLOUD 0.01%
#  - ANALISTA CONTABLE  0.01%
#  - SERVICIO TÉCNICO  0.01%
#  - FUNCTIONAL ANALYST JR 0.01%
#  - OPERATION LEAD 0.01%
#  - TECHNICAL SUPPORT 0.01%
#  - ANALISTA IT 0.01%
#  - INTEGRATION DEVELOPER 0.01%
#  - PROFESOR DE TECNOLOGÍA DE LA INFORMACIÓN 0.01%
#  - APPDYNAMICS ENGINEER 0.01%
#  - RESEARCH 0.01%
#  - FUNCTIONAL 0.01%
#  - TECHNICAL ACCOUNT MANAGER 0.01%
#  - ANALISTA DE SISTEMA 0.01%
#  - INGENIERO DE LABORATORIO 0.01%
#  - GERENTE 0.01%
#  - ATLASSIAN SPECIALIST 0.01%
#  - RPA & ETL DEVELOPER 0.01%
#  - MEZCLA DE SYSADMIN, NETWORKING, DBA... DE TODO UN POCO 0.01%
#  - FULL STACK Y BI 0.01%
#  - NLP ANALYST 0.01%
#  - ANALISTA DE METODOLOGÍA 0.01%
#  - COMPUTATIONAL LINGUIST JUNIOR 0.01%
#  - ANALISTA NPL 0.01%
#  - CONSULTOR DE IMPLEMENTACIÓN 0.01%
#  - NOC 0.01%
#  - ANALISTA DE SISTEMAS 0.01%
#  - TRAFFICKER 0.01%
#  - CALIDAD 0.01%
#  - RRHH 0.01%
#  - CREATIVE COPYWRITER 0.01%
#  - PIPELINE TECHNICAL ARTIST 0.01%
#  - DESARROLLADOR PLSQL + DESARROLLADOR WEB + SOPORTE-ANALISTA FUNCIONAL 0.01%
#  - ANALISTA SEGURIDAD INFORMATICA 0.01%
#  - SR STAFF ENGINEER 0.01%
#  - TECH MANAGER 0.01%
#  - ANALISTA FUNCIONAL SR 0.01%
#  - JEFE DE IT 0.01%
#  - INGENIERO DE SOPORTE 0.01%
#  - GERENTE DE ATRACCIÓN DE TALENTOS Y COMERCIAL 0.01%
#  - PRODUCT DESIGNER 0.01%
#  - SENIOR PRODUCT OWNER 0.01%
#  - PRODUCT SUPPORT 0.01%
#  - INGENIERO EN INFORMATICA 0.01%
#  - RESPONSABLE DE MARKETING 0.01%
#  - DATA MODELING ENGINEER 0.01%
#  - CTO 0.01%
#  - ANALISIS FUNCIONAL 0.01%
#  - MEDIA COMUNNICATIONS 0.01%
#  - ANALYST 0.01%
#  - UI  0.01%
#  - JEFE DE SOPORTE Y OPERACIONES 0.01%
#  - SOY EL DPTO DE SISTEMAS EN UNA ESCUELA DE 80 PC Y 400 POR WIFI..HAGO TODO 0.01%
#  - CYBER SECURITY 0.01%
#  - ANALYTICS ENGINEER 0.01%
#  - CONVERSATIONAL DESIGNER 0.01%
#  - ACCESS MANAGMENT SR 0.01%
#  - SISTEMAS 0.01%
#  - PRODUCTORA DE EVENTOS 0.01%
#  - IT SPECIALIST 0.01%
#  - PRODUCT ANALYST 0.01%
#  - SUPPORT SENIOR 0.01%
#  - SOPORTE TRANSACCIONAL 0.01%
#  - SUPORT L2 0.01%
#  - ERP DEVELOPER 0.01%
#  - TEST AUTOMATION ENGINEER 0.01%
#  - FIELD OPERATIONS / TELECOMMUNICATIONS 0.01%
#  - RESEARCH ENGINEER 0.01%
#  - RESPONSABLE DE ÁREA DE SISTEMAS  0.01%
#  - SOPORTE NIVEL 2 0.01%
#  - ENCARGADO ÁREA DE SISTEMAS 0.01%
#  - ATLASSIAN CONSULTANT 0.01%
#  - BUSINESS ANALYST Y SCRUM MASTER 0.01%
#  - NOC  0.01%
#  - FULL STACK DEVELOPER 0.01%
#  - SUPPORTENGINEER 0.01%
#  - DOCENCIA 0.01%
#  - CLOUDENGINEER/DEV/DEVOPS 0.01%
#  - ARTIST 0.01%
#  - PRODUCT LEAD 0.01%
#  - TEAM LEAD 0.01%
#  - PROJECT MANAGER, PRODUCT MANAGER, DEVELOPER, SRE 0.01%
#  - TECNICO TELECOMUNICACIONES 0.01%
#  - LABORATORIO UNIVERSITARIO 0.01%
#  - ADMINISTRATIVO  0.01%
#  - SITE SUPPORT 0.01%
#  - WORDPRESS 0.01%
#  - CLOUD 0.01%
#  - IT SERVICES 0.01%
#  - LEAD DATA ENGINEER 0.01%
#  - PROJECT LEADER 0.01%
#  - ADMINISTRATIVA 0.01%
#  - CRO 0.01%
#  - TRAINEE 0.01%
#  - SECURITY ENGINEER 0.01%
#  - TECNICO DE CALLE 0.01%
#  - REDACTOR Y EDITOR, DISEÑO, CONTENIDOS 0.01%
#  - PRODUCT SECURITY 0.01%
#  - ON SITE SUPPORT 0.01%
#  - SAP BASIS ADMINISTRATOR 0.01%
#  - CRM DEVELOPER 0.01%
#  - INTEGRATOR 0.01%
#  - ADMINISTRATIVA  0.01%
#  - SOPORTE TECNICO DE INFRAESTRUCTURA 0.01%
#  - ADMINISTRATIVO DE DEPOSITO 0.01%
#  - POSTPRODUCER 0.01%
#  - DEVOPS, DESARROLLO, DISEÑO, INSTALO ARQUITECTURA, MONITOREO, ETC 0.01%
#  - SYSTEMS INTEGRATION ANALYST 0.01%
#  - PEOPLE CARE 0.01%
#  - DOCENTE UNIVERSITARIO 0.01%
#  - HELPDESL / TECNICO EN REPARACION DE PC, NOTEBOOKS E IMPRESORAS / TECNICO INSTALADOR DE HFC Y FTTH 0.01%
#  - SECURITY ANALIST 0.01%
#  - DE TODO UN POCO 0.01%
#  - FULLSTACK 0.01%
#  - ESPECIALISTA EN YACIMIENTO DIGITAL 0.01%
#  - MEZCLA ENTRE HELPDESK Y ADMIN BASE DE DATOS 0.01%
#  - PRODUCTIVITY & COLLABORATION 0.01%
#  - DBA / DEVELOPER 0.01%
#  - AYUDANTE EN CURSOS DE PROGRAMACIÓN 0.01%
#  - ADMINISTRADOR DE SISTEMA ERP 0.01%
#  - GROWTH ENGINEER  0.01%
#  - PROGRAMADOR 0.01%
#  - TECNOLOGY 0.01%
#  - JEFE DIVISIÓN INFORMÁTICA 0.01%
#  - SUBJECT MATTER EXPERT 0.01%
#  - BI ENGINEER 0.01%
#  - DE TODO 0.01%
#  - ANALISTA FUNCIONAL  0.01%
#  - DIGITAL MARKETING 0.01%
#  - ANALISTA FUNCIONAL Y COORDINADORA DE GRUPO DE MANTENIMIENTO  0.01%
#  - TI-INFRAESTRUCTURA 0.01%
#  - SECURITY RESEARCH 0.01%
#  - SUPPORT 0.01%
#  - RESPONSABLE IT 0.01%
#  - PROFESOR DE INFORMÁTICA 0.01%
#  - FRONTEND CHAPTER LEAD 0.01%
#  - SOFTWARE INGENIERO 0.01%
#  - TUTOR 0.01%
#  - TECHNICAL SUPPORT (NOT HELP DESK) 0.01%
#  - PRINCIPAL SE 0.01%
#  - BI DEVELOPER 0.01%
#  - ARCHITECTURE ENGINEERING  0.01%
#  - PMO MANAGER 0.01%
#  - INSTRUCTOR 0.01%
#  - CHAPTER LEAD 0.01%
#  - PROGRAMADOR DE AUTOMATAS 0.01%
#  - RESPONSABLE DE INFRAESTRUCTURA 0.01%
#  - DEPOSITO 0.01%
#  - UI - FRONTEND 0.01%
#  - CIO 0.01%
#  - CASHIER 0.01%
#  - OPERATIONS LEAD 0.01%
#  - FREELANCE 0.01%
#  - APPLICATION SUPPORT 0.01%
#  - DBA+FRONTEND 0.01%
#  - EDUCATION 0.01%
#  - IT SUPPORT 0.01%
#  - BUSINESS ANALYST, QA / TESTER, PROJECT MANAGER,PRODUCT MANAGER 0.01%
#  - REFERENTE DE AREA  0.01%
#  - DESARROLLOS DE MODELOS FISICOS EN C, C++ O PYTHON, PARA SER INTEGRADOS EN UN SOFTWARE DE SIMULACION DE VUELO 0.01%
#  - ADMINISTRACION 0.01%
#  - REDACCIÓN 0.01%
#  - TECNICO 0.01%
#  - ADMINISTRACIÓN 0.01%
#  - REDACTOR CREATIVO 0.01%
#  - TELECOMUNICACIONES  0.01%
#  - DESARROLLADOR ETL 0.01%
#  - ANALISTA IMPLEMENTADOR 0.01%
#  - JEFE DE ÁREA DE SISTEMAS 0.01%
#  - ESTRUCTURADO 0.01%
#  - SOPORTE DE CAMPO 0.01%
#  - AUDITORIA 0.01%
#  - INGENIERO ELECTRÓNICO 0.01%
#  - IMPLEMENTADOR 0.01%
#  - SYSADMIN / STORAGE / BACKUP / NETWORKING 0.01%
#  - COMMUNITY MANAGER EN IT 0.01%
#  - TI GENERALISTA 0.01%
#  - ATENCIÓN AL CLIENTE EN NARANJA X 0.01%
#  - ALLIANCES MANAGER (INDIRECT SALES) 0.01%
#  - DATA QUALITY 0.01%
#  - APRENTICE 0.01%
#  - INGENIERO INFRAESTRUCTURAS DE VIRTUALIZACION 0.01%
#  - TEACHER 0.01%
#  - PROFESOR DE TEATRO  0.01%
#  - TI 0.01%
#  - MIX ENTRE SYSADMIN Y DEVELOPER PASANDO POR DBA 0.01%
#  - CHEF 0.01%
#  - ARTESANAL 0.01%
#  - TECHNICAL SUPPORT ENGINEER 0.01%
#  - SALESFORCE ADMIN/DEVELOPER 0.01%
#  - ANALISTA FUNCIONAL DE SISTEMAS 0.01%
#  - INDEPENDIENTE  0.01%
#  - SOPORTE ON SITE 0.01%
#  - APP ANALYST 0.01%
#  - CAJERA 0.01%

# %% [markdown]
# 4. Printear porcentaje de respuesta para las preguntas:
# * ¿Contribuís a proyectos Open Source?
# * ¿Programás por hobbie?

# %%
dic_OpenSources={}
    
for row in list_data:
    answer = row[preguntas["¿Contribuís a proyectos open source?"]].upper()
    if answer in dic_OpenSources: 
        dic_OpenSources[answer] += 1
    else:     
        dic_OpenSources[answer] = 1

no_answer =0        
for key in dic_OpenSources:
        if key == "":
            no_answer += dic_OpenSources [key]
            
TotalAnswers = (len(list_data) - no_answer) * 100 / len(list_data)
Porcentaje_si = dic_OpenSources['SÍ'] * 100/ (dic_OpenSources['SÍ'] + dic_OpenSources['NO'])
Porcentaje_no = dic_OpenSources['NO'] * 100/ (dic_OpenSources['SÍ'] + dic_OpenSources['NO'])

print(str(round(TotalAnswers, 2)) + '% de las personas encuestadas contestaron la pregunta "¿Contribuís a proyectos Open Source?"')
print(str(round(Porcentaje_si, 2)) + '% de las respuestas fueron afmirmativas, ' + str(round(Porcentaje_no, 2)) + '% fueron negativas.')
print("""""")
# Out:
# 50.56% de las personas encuestadas contestaron la pregunta "¿Contribuís a proyectos Open Source?"
# 14.97% de las respuestas fueron afmirmativas, 85.03% fueron negativas.

# %%
dic_ProgramasComoHobbie={}
    
for row in list_data:
    answer = row[preguntas["¿Programás como hobbie?"]].upper()
    if answer in dic_ProgramasComoHobbie: 
        dic_ProgramasComoHobbie[answer] += 1
    else:     
        dic_ProgramasComoHobbie[answer] = 1

no_answer =0        
for key in dic_ProgramasComoHobbie:
        if key == "":
            no_answer += dic_ProgramasComoHobbie [key]
            
TotalAnswers = (len(list_data) - no_answer) * 100 / len(list_data)
Porcentaje_si = dic_ProgramasComoHobbie['SÍ'] * 100/ (dic_ProgramasComoHobbie['SÍ'] + dic_ProgramasComoHobbie['NO'])
Porcentaje_no = dic_ProgramasComoHobbie['NO'] * 100/ (dic_ProgramasComoHobbie['SÍ'] + dic_ProgramasComoHobbie['NO'])

print(str(round(TotalAnswers, 2)) + '% de las personas encuestadas contestaron la pregunta "¿Programás como hobbie?"')
print(str(round(Porcentaje_si, 2)) + '% de las respuestas fueron afmirmativas, ' + str(round(Porcentaje_no, 2)) + '% fueron negativas.')
print("""""")
# Out:
# 50.56% de las personas encuestadas contestaron la pregunta "¿Programás como hobbie?"
# 56.06% de las respuestas fueron afmirmativas, 43.94% fueron negativas.

# %% [markdown]
# 5. Printear porcentaje por seniority según años de experiencia, el mapeo es:
# ```
# Junior: de 0 hasta 2 años.
# Semi-Senior: de 2 años inclusive hasta 5 años.
# Senior: desde 5 años inclusive.
# ```

# %%
dic_WorkExperience={
"Junior": 0,
"Semi-Senior": 0,
"Senior": 0, 
}

for row in list_data:
    answer = float(row[preguntas["Años de experiencia"]])
    if answer < 2:
        dic_WorkExperience["Junior"] += ((1 / len(list_data)) * 100)
    elif 2 <= answer < 5:
        dic_WorkExperience["Semi-Senior"] += ((1 / len(list_data)) * 100)
    #Asumo que una persona no va a trabajar + de 70 años
    elif 5 <= answer < 71:
        dic_WorkExperience["Senior"] += ((1 / len(list_data)) * 100)
        
for key in dic_WorkExperience:
        print(f" - {key} {round(dic_WorkExperience[key],2)}%")
# Out:
#  - Junior 15.93%
#  - Semi-Senior 26.63%
#  - Senior 57.43%

# %% [markdown]
# 6. Printear porcentaje de personas encuestadas por años en la compañía actual y por años en el puesto actual.

# %%
#Me agrupo por rangos de años:
#de 0 hasta 5 años
#de 5 hasta 15 años
#más de 15 años

dic_years_in_company = {
    "0-2": 0,
    "2-5": 0,
    "5-10": 0,
    "10-15": 0,
    ">15": 0,
}

dic_years_in_position = {
    "0-2": 0,
    "2-5": 0,
    "5-10": 0,
    "10-15": 0,
    ">15": 0,
}

set_years_in_company = set()
set_years_in_position = set()

for row in list_data:
    answer = float(row[preguntas["Años en la empresa actual"]])
    set_years_in_company.add(answer)
    if answer < 2:
        dic_years_in_company["0-2"] += ((1 / len(list_data)) * 100)
    elif 2 <= answer < 5:
        dic_years_in_company["2-5"] += ((1 / len(list_data)) * 100)
    elif 5 <= answer < 10:
        dic_years_in_company["5-10"] += ((1 / len(list_data)) * 100)
    elif 10 <= answer < 15:
        dic_years_in_company["10-15"] += ((1 / len(list_data)) * 100)
    elif answer > 15:
        dic_years_in_company[">15"] += ((1 / len(list_data)) * 100)


for row in list_data:
    answer = float(row[preguntas["Años en el puesto actual"]])
    set_years_in_position.add(answer)
    if answer < 2:
        dic_years_in_position["0-2"] += ((1 / len(list_data)) * 100)
    elif 2 <= answer < 5:
        dic_years_in_position["2-5"] += ((1 / len(list_data)) * 100)
    elif 5 <= answer < 10:
        dic_years_in_position["5-10"] += ((1 / len(list_data)) * 100)
    elif 10 <= answer < 15:
        dic_years_in_position["10-15"] += ((1 / len(list_data)) * 100)
    elif answer > 15:
        dic_years_in_position[">15"] += ((1 / len(list_data)) * 100)
        
for key in dic_years_in_company:
        print(f" - {key} Años en la empresa actual {round(dic_years_in_company[key],2)}%") 
print("""""")
for key in dic_years_in_position:
        print(f" - {key} Años en el puesto actual {round(dic_years_in_position[key],2)}%")
# Out:
#  - 0-2 Años en la empresa actual 52.93%
#  - 2-5 Años en la empresa actual 27.33%
#  - 5-10 Años en la empresa actual 11.49%
#  - 10-15 Años en la empresa actual 5.04%
#  - >15 Años en la empresa actual 2.3%
#
#  - 0-2 Años en el puesto actual 50.3%
#  - 2-5 Años en el puesto actual 32.33%
#  - 5-10 Años en el puesto actual 11.59%
#  - 10-15 Años en el puesto actual 4.27%
#  - >15 Años en el puesto actual 0.82%

# %% [markdown]
# 7. Printear porcentajes de nivel de educación formal y estado, es decir: % educación secundaria, terciaria, universitaria, postgrado, doctorado, postdoctorado, completo, incompleto y en curso para cada uno.

# %%
set_educational_level = set()

for row in list_data:
    answer1 = row[preguntas["Nivel de estudios alcanzado"]].upper()
    answer2 = row[preguntas["Estado"]].upper()
    set_educational_level.add(answer1 + " " + answer2)
    #set_educational_level.add((row["Nivel de estudios alcanzado"], row["Estado"]))
    
list_educational_level = list(set_educational_level)
list_educational_level.sort()
list_educational_level.remove(' ')

dic_educational_level = {}

for i in list_educational_level:
    number_of_cases = 0
    for row in list_data:
        answer1 = row[preguntas["Nivel de estudios alcanzado"]].upper()
        answer2 = row[preguntas["Estado"]].upper()
        if answer1 + " " + answer2 == i:
            number_of_cases += 1
    dic_educational_level.update({i:number_of_cases})

number_education_answers = 0    
for key in dic_educational_level:
    number_education_answers += dic_educational_level[key]

for key in dic_educational_level:
    dic_educational_level[key] = (dic_educational_level[key] * 100) / number_education_answers 

sorted_dic_educational_level = dict(sorted(dic_educational_level.items(), key=lambda item: item[1], reverse=True))

for key in sorted_dic_educational_level:
    print(f" - {key} {round(sorted_dic_educational_level[key],2)}%")
# Out:
#  - UNIVERSITARIO EN CURSO 25.45%
#  - UNIVERSITARIO COMPLETADO 25.19%
#  - UNIVERSITARIO INCOMPLETO 17.85%
#  - TERCIARIO COMPLETADO 8.84%
#  - SECUNDARIO COMPLETADO 5.79%
#  - TERCIARIO EN CURSO 4.75%
#  - POSGRADO COMPLETADO 4.55%
#  - TERCIARIO INCOMPLETO 3.71%
#  - POSGRADO EN CURSO 1.64%
#  - POSGRADO INCOMPLETO 0.75%
#  - SECUNDARIO INCOMPLETO 0.46%
#  - DOCTORADO COMPLETADO 0.37%
#  - DOCTORADO EN CURSO 0.29%
#  - SECUNDARIO EN CURSO 0.14%
#  - DOCTORADO INCOMPLETO 0.06%
#  - POSDOCTORADO COMPLETADO 0.06%
#  - POSDOCTORADO EN CURSO 0.03%
#  - POSDOCTORADO INCOMPLETO 0.03%
#  - PRIMARIO INCOMPLETO 0.03%

# %% [markdown]
# 8. Formatear las carreras universitarias:
# - Nombres capitalizados
# - Reemplazar vocales con tilde por vocales sin tilde.
# - Reemplazar `ñ` por `n`
# - *lic*, *lic.* por Licenciatura
# - *tec*, *tec.* por Tecnucatura
# * *cs, *cs.* por Ciencias
# * *ed, ed.* por Educación
# * Transformaciones que se consideren necesarias
#
# Printear porcentaje según carrera

# %%
for row in list_data:
    row[preguntas["Carrera"]] = row[preguntas["Carrera"]].upper()
    
def answer_replace_str (question, str_to_replace, replacement):
    for row in list_data:
        if str_to_replace in row[preguntas[question]]:
            row[preguntas[question]] = row[preguntas[question]].replace(str_to_replace, replacement)    

answer_replace_str ("Carrera",'Í', 'I')
answer_replace_str ("Carrera",'Ó', 'O')
answer_replace_str ("Carrera",'Á', 'A')
answer_replace_str ("Carrera",'É', 'E')
answer_replace_str ("Carrera",'Ú', 'U')
answer_replace_str ("Carrera",'Ñ', 'N')
answer_replace_str ("Carrera",'LIC.', 'LICENCIATURA')
answer_replace_str ("Carrera",'LIC ', 'LICENCIATURA ')
answer_replace_str ("Carrera",'LIC,', 'LICENCIATURA')
answer_replace_str ("Carrera",'LICENCIADO', 'LICENCIATURA')
answer_replace_str ("Carrera",'TEC,', 'TECNICATURA')
answer_replace_str ("Carrera",'TEC.', 'TECNICATURA')
answer_replace_str ("Carrera",'TEC ', 'TECNICATURA ')
answer_replace_str ("Carrera",'TECNICO', 'TECNICATURA')
answer_replace_str ("Carrera",'CS.', 'CIENCIAS')
answer_replace_str ("Carrera",'CS,', 'CIENCIAS')
answer_replace_str ("Carrera",'CS ', 'CIENCIAS ')
answer_replace_str ("Carrera",'ED.', 'EDUCACION')
answer_replace_str ("Carrera",'ED,', 'EDUCACION')
answer_replace_str ("Carrera",'ED ', 'EDUCACION ')
answer_replace_str ("Carrera",'ING.', 'INGENIERIA')
answer_replace_str ("Carrera",'ING ', 'INGENIERIA ')
answer_replace_str ("Carrera",'ING,', 'INGENIERIA')
answer_replace_str ("Carrera",'-', '')
answer_replace_str ("Carrera",'.', '')

# %%
dic_career={}
    
for row in list_data:
    answer = row[preguntas["Carrera"]].upper()
    if answer in dic_career: 
        dic_career[answer] += 1
    else:     
        dic_career[answer] = 1

no_answer =0        
for key in dic_career:
        if key == "":
            no_answer += dic_career [key]

TotalAnswers = len(list_data) - no_answer
del(dic_career[''])

sorted_dic_career = dict(sorted(dic_career.items(), key=lambda item: item[1], reverse=True))

for key in sorted_dic_career:
    print(f" - {key} {round(sorted_dic_career[key] / TotalAnswers * 100, 2)}%")
# Out:
#  - INGENIERIA EN SISTEMAS DE INFORMACION 19.01%
#  - INGENIERIA EN INFORMATICA 11.35%
#  - ANALISTA DE SISTEMAS 8.69%
#  - LICENCIATURA EN SISTEMAS DE INFORMACION 5.66%
#  - LICENCIATURA EN CIENCIAS DE LA COMPUTACION 5.66%
#  - LICENCIATURA EN INFORMATICA 4.3%
#  - TECNICATURA EN PROGRAMACION 3.39%
#  - INGENIERIA ELECTRONICA 3.0%
#  - INGENIERIA EN COMPUTACION 2.82%
#  - DISENO GRAFICO 2.48%
#  - TECNICATURA SUPERIOR EN PROGRAMACION 2.36%
#  - LICENCIATURA EN ADMINISTRACION 1.73%
#  - TECNICATURA EN INFORMATICA 1.57%
#  - LICENCIATURA EN ANALISIS DE SISTEMAS 1.18%
#  - INGENIERIA INDUSTRIAL 1.18%
#  - ANALISTA PROGRAMADOR 1.12%
#  - INGENIERIA EN SOFTWARE 1.06%
#  - ANALISTA PROGRAMADOR UNIVERSITARIO 1.0%
#  - INGENIERIA EN TELECOMUNICACIONES 0.97%
#  - ANALISTA DE COMPUTACION 0.88%
#  - TECNICATURA SUPERIOR EN SISTEMAS INFORMATICOS 0.88%
#  - TECNICATURA EN SISTEMAS 0.85%
#  - DISENO MULTIMEDIAL 0.85%
#  - TECNICATURA SUPERIOR EN ANALISIS DE SISTEMAS 0.7%
#  - ANALISTA UNIVERSITARIO DE SISTEMAS 0.61%
#  - TECNICATURA ELECTRONICA 0.54%
#  - TELECOMUNICACIONES 0.51%
#  - TECNICATURA EN COMPUTACION 0.51%
#  - LICENCIATURA EN PSICOLOGIA 0.42%
#  - DISENO DE IMAGEN Y SONIDO 0.33%
#  - PSICOLOGIA 0.33%
#  - SISTEMAS DE INFORMACION 0.27%
#  - DISENO INDUSTRIAL 0.21%
#  - LICENCIATURA EN CIENCIA POLITICA 0.21%
#  - LICENCIATURA EN FISICA 0.18%
#  - LICENCIATURA EN RELACIONES DEL TRABAJO 0.18%
#  - MARKETING 0.18%
#  - LICENCIATURA EN ECONOMIA 0.15%
#  - LICENCIATURA EN COMUNICACION 0.15%
#  - CONTADOR PUBLICO 0.15%
#  - LICENCIATURA EN SISTEMAS 0.15%
#  - LICENCIATURA EN SOCIOLOGIA 0.12%
#  - SOCIOLOGIA 0.12%
#  - TECNICATURA EN DESARROLLO WEB 0.12%
#  - LETRAS 0.12%
#  - COMUNICACION SOCIAL 0.12%
#  - LICENCIATURA EN CIENCIAS DE LA COMUNICACION 0.12%
#  - PROFESORADO DE INGLES 0.12%
#  - LICENCIATURA EN BIOTECNOLOGIA 0.09%
#  - ARQUITECTURA 0.09%
#  - INGENIERIA QUIMICA 0.09%
#  - MEDICINA 0.09%
#  - INGENIERIA DE SONIDO 0.09%
#  - LICENCIATURA EN CIENCIAS MATEMATICAS 0.09%
#  - LICENCIATURA EN CIENCIAS BIOLOGICAS 0.09%
#  - LICENCIATURA EN GESTION DE LA TECNOLOGIA 0.09%
#  - LICENCIATURA EN CIENCIAS DE DATOS 0.09%
#  - LICENCIATURA EN ARTES MULTIMEDIALES 0.09%
#  - DISENO WEB 0.09%
#  - LICENCIATURA EN RELACIONES INTERNACIONALES 0.09%
#  - NINGUNA 0.09%
#  - ECONOMIA 0.09%
#  - LICENCIATURA EN MATEMATICAS 0.09%
#  - LICENCIATURA EN PUBLICIDAD 0.09%
#  - LICENCIATURA EN GESTION DE TECNOLOGIA 0.09%
#  - ARTES VISUALES 0.09%
#  - LICENCIATURA EN CIENCIAS FISICAS 0.09%
#  - INGENIERIA MECATRONICA 0.09%
#  - LICENCIATURA EN COMUNICACION SOCIAL 0.09%
#  - LICENCIATURA EN RECURSOS HUMANOS 0.09%
#  - INGENIERIA CIVIL 0.09%
#  - LICENCIATURA EN HISTORIA 0.06%
#  - LICENCIATURA EN TURISMO 0.06%
#  - RECURSOS HUMANOS 0.06%
#  - LICENCIATURA EN CIENCIA DE DATOS 0.06%
#  - RRII 0.06%
#  - INGENIERIA MECANICA 0.06%
#  - TECNICATURA EN DESARROLLO DE VIDEOJUEGOS 0.06%
#  - FISICA 0.06%
#  - PROFESORADO DE HISTORIA 0.06%
#  - ABOGACIA 0.06%
#  - RRHH 0.06%
#  - LICENCIATURA EN ESTADISTICA 0.06%
#  - CIENCIA POLITICA 0.06%
#  - LICENCIATURA EN CIENCIAS DE LA COMUNICACION SOCIAL 0.06%
#  - BIOINGENIERIA 0.06%
#  - EDICION 0.06%
#  - LICENCIATURA EN TECNOLOGIA DE LA INFORMACION 0.06%
#  - INGENIERIA ELECTRICA 0.06%
#  - ACTUARIO 0.06%
#  - LICENCIATURA EN MATEMATICA 0.06%
#  - TECNICATURA EN DESARROLLO DE SOFTWARE 0.06%
#  - RELACIONES PUBLICAS 0.06%
#  - RELACIONES INTERNACIONALES 0.06%
#  - ADMINISTRACION 0.06%
#  - LICENCIATURA EN BIOINFORMATICA 0.06%
#  - INGENIERIA BIOMEDICA 0.06%
#  - LICENCIATURA EN RELACIONES PUBLICAS E INSTITUCIONALES 0.06%
#  - LICENCIATURA EN PERIODISMO 0.06%
#  - TECNICATURA SUPERIOR EN DESARROLLO DE SOFTWARE 0.06%
#  - TECNICATURA EN DISENO Y PROGRAMACION DE VIDEOJUEGOS 0.06%
#  - LICENCIATURA EN RRHH 0.06%
#  - INGENIERIA EN SISTEMAS 0.06%
#  - TECNICATURA SUPERIOR EN DESARROLLO DE SOFTWARE  0.06%
#  - INGENIERIA DE SISTEMAS 0.06%
#  - MBA 0.06%
#  - INGENIERIA EN TECNOLOGIAS DE LA INFORMACION 0.06%
#  - LICENCIATURA EN REDES Y COMUNICACION DE DATOS  0.03%
#  - LICENCIATURA PSICOLOGIA 0.03%
#  - ELECTROMECANICA 0.03%
#  - GEOLOGIA  0.03%
#  - ANALISTA EN REDES INFORMATICAS 0.03%
#  - CERTIFIEDUCACION TECH DEVELOPER 0.03%
#  - LICENCIATURA EN RRLL 0.03%
#  - TECNICATURA UNIVERSITARIO EN DESARROLLO WEB 0.03%
#  - NINGUNA DE LAS ANTERIORES 0.03%
#  - LICENCIATURA EN COMERCIALIZACION 0.03%
#  - TECNICATURA UNIVERSITARIA EN SISTEMAS INFORMATICOS 0.03%
#  - LICENCIATURA EN GESTION DE SISTEMAS 0.03%
#  - TECNICATURA SUPERIOR EN SOPORTE DE INFRAESTRUCTURAS IT  0.03%
#  - LICENCIATURA EN TECNOLOGIAS DE INFORMACION  0.03%
#  - TECNICATURA EN INFRAESTRUCTURA TECNOLOGICA  0.03%
#  - CONSERVATORIO DE MUSICA 0.03%
#  - DISENO DE INTERIORES 0.03%
#  - LICENCIATURA EN MUSICA 0.03%
#  - CIENCIAS BIOLOGICAS  0.03%
#  - INGENIERIA DE SONIDO  0.03%
#  - LICENCIATURA ADMIN 0.03%
#  - LICENCIATURA EN GESTION AMB + MBT 0.03%
#  - TURISMO 0.03%
#  - TECNICATURA DE SONIDO 0.03%
#  - LICENCIATURA EN ADMINISTRACION DE SISTEMAS Y EMPRESAS 0.03%
#  - BIOLOGIA 0.03%
#  - ARQUITECTURA  0.03%
#  - NO ESTUDIE 0.03%
#  - MAESTRIA EN IT 0.03%
#  - CIENCIAS DE LA COMUNICACION 0.03%
#  - PROFESOR DE INGLES 0.03%
#  - CONTADURIA 0.03%
#  - LICENCIATURA EN PUBLICIDAD Y RELACIONES PUBLICAS 0.03%
#  - LICENCIATURA RELACIONES DEL TRABAJO, DIPLOMATURA EN USABILIDAD Y ACCESIBILIDAD  0.03%
#  - ESTUDIO POR ACADEMIAS VIRTUALES 0.03%
#  - SOY ABOGADO HACIENDO UN MASTER EN RRII 0.03%
#  - PHD IN COMPUTER SCIENCE 0.03%
#  - MEDICO INFORMATICO 0.03%
#  - COMUNICACION 0.03%
#  - FILOLOGIA HISPANICA 0.03%
#  - GESTION DE MEDIOS Y ENTRETENIMIENTO 0.03%
#  - SOPORTE EN INFRAESTRUCTURAS 0.03%
#  - TENICATURA EN PERIODISMO GENERAL 0.03%
#  - TECNICATURA EN INFRAESTRUCTURAS DE TI 0.03%
#  - INGENIERIA 0.03%
#  - LICENCIATURA EN GEOLOGIA 0.03%
#  - LICENCIATURA EN CIENCIAS QUIMICAS + MAESTRIA EN CIENCIA DE DATOS 0.03%
#  - TRADUCTORA PUBLICA INGLES  0.03%
#  - LICENCIATURA EN GESTION DE TECNOLOGIA INFORMATICA 0.03%
#  - CIENCIAS DE LA COMUNICACION SOCIAL 0.03%
#  - ANTROPOLOGIA 0.03%
#  - TRADUCTORADO PUBLICO 0.03%
#  - TECNICATURA SUPERIOR EN ADMINISTRACION DE SISTEMAS 0.03%
#  - DECORADOR PROFESIONAL 0.03%
#  - INGENIERIA AERONAUTICA 0.03%
#  - TECNICATURA EN DISENO DE SIMULADORES VIRTUALES 0.03%
#  - TSP ABANDONADA3X 0.03%
#  - FILOSOFIA 0.03%
#  - INGENIERIA SONIDO 0.03%
#  - DISENO ARQUITECTONICO 0.03%
#  - TECNICATURA EN PERIODISMO 0.03%
#  - GEOLOGIA 0.03%
#  - DIPLOMA EN EXPERIENCIAS DIGITALES 0.03%
#  - VETERINARIA 0.03%
#  - TECNICATURA ELECTROMECANICO 0.03%
#  - PERIODISMO 0.03%
#  - MAESTRIA EN DIRECCION ESTRATEGICA Y TECNOLOGICA 0.03%
#  - MUSICA 0.03%
#  - TECNICATURA EN EDICION UBA 0.03%
#  - LICENCIATURA EN CIENCIAS ANTROPOLOGICAS 0.03%
#  - BACHILLERATO 0.03%
#  - LICENCIATURA EN CIENCIAS POLITICAS 0.03%
#  - DISENO Y ADMINISTRACION DE SITIOS WEB 0.03%
#  - LICENCIATURA EN DIRECCION ESCENICA 0.03%
#  - DERECHO 0.03%
#  - BOOTCAMP DE DESARROLLO WEB 0.03%
#  - MASTER IN BUSINESS AND TECH 0.03%
#  - SIN TITULO UNIVERSITARIO 0.03%
#  - ECONOMICAS 0.03%
#  - MAESTRIA EN RECURSOS HUMANOS 0.03%
#  - LICENCIATURA EN CIENCIAS QUIMICAS  0.03%
#  - LICENCIATURA EN COMERCIALIZACION  0.03%
#  - PERIODISMO  0.03%
#  - TRADUCTORADO E INTERPRETARIADO DE INGLES  0.03%
#  - PSICOLOGIA  0.03%
#  - TECNICATURA SUPERIOR EN INFORMATICA APLICADA 0.03%
#  - TENGO TITULO DE LICENCIA EN CIENCIAS MATEMATICAS  0.03%
#  - LICENCIATURA EN GESTION DE LA INFORMACION 0.03%
#  - FISICA APLICADA 0.03%
#  - TRABAJO SOCIAL 0.03%
#  - PRODUCTORA Y DIRECTORA PARA RADIO Y TV 0.03%
#  - N/A 0.03%
#  - LICENCIATURA EN GEOGRAFIA 0.03%
#  - CONTADOR 0.03%
#  - FINANZAS 0.03%
#  - TECNICA ELECTRONICA 0.03%
#  - TECNICATURA SUPERIOR EN ADM DE LA PRODUCCION GRAFICA 0.03%
#  - LICENCIATURA EN SOCIOLOGIA  MASTER EN DATA SCIENCE 0.03%
#  - CIENCIA DE DATOS 0.03%
#  - LICENCIATURA EN ADMINISTRACION Y SISTEMAS 0.03%
#  - TECNICATURA UNIVERSITARIO EN SONIDO 0.03%
#  - TECNICATURA SUPERIOR EN ANALISIS, DESARROLLO Y PROGRAMACION DE APLICACIONES 0.03%
#  - DESARROLLO WEB Y MOBILE 0.03%
#  - DISENO GRAFICO MULTIMEDIAL Y ANALISTA DE SISTEMAS 0.03%
#  - PUBLICIDAD 0.03%
#  - MAESTRIA  0.03%
#  - TRADUCCION 0.03%
#  - CARRERA DE GRADO EN CURSO 0.03%
#  - LINGUISTICA 0.03%
#  - LICENCIATURA EN COMUNICACION  MULTIMEDIA 0.03%
#  - DISENO Y ADMINISTRACION WEB 0.03%
#  - ADMINISTRACION BANCARIA 0.03%
#  - TRADUCTORADO Y PSICOLOGIA SOCIAL 0.03%
#  - LICENCIATURA Y PROFESORADO EN ARTES (ORIENTACION MUSICA) 0.03%
#  - LICENCIATURA EN TECNOLOGIAS DE LA INFORMACION 0.03%
#  - MAESTRO MAYOR DE OBRAS 0.03%
#  - LICENCIATURA EN ARTES ELECTRONICAS 0.03%
#  - LICENCIATURA HIGIENE Y SEGURIDAD 0.03%
#  - INGENIERIA EN SONIDO 0.03%
#  - VIDEO JUEGOS 0.03%
#  - TECNICATURA EN SOFTWARE LIBRE 0.03%
#  - LICENCIATURA EN QUIMICA 0.03%
#  - PROFESOR EN DISCIPLINAS INDUSTRIALES  0.03%
#  - CIENCIAS DE LA COMUNICACION SOCIAL  0.03%
#  - LICENCIATURA EN PSICOLOGIA  0.03%
#  - LITERATURA 0.03%
#  - PROFESORADO EN ENSENANZA MEDIA Y SUPERIOR EN MATEMATICAS 0.03%
#  - PROFESORADO DE EDUCACION FISICA 0.03%
#  - LICENCIATURA EN COMUNICACION AUDIOVISUAL  0.03%
#  - SOY BACHILLER EN HUMANIDADES Y CIENCIAS SOCIALES 0.03%
#  - SOCIOLOGIA  0.03%
#  - LICENCIATURA EN GESTION DE SISTEMAS DE AUTOMATIZACION Y ROBOTICA 0.03%
#  - LICENCIATURA EN CIENCIAS SOCIALES 0.03%
#  - PROGRAMADOR Y DISENADOR DE SIMULADORES VIRTUALES 0.03%
#  - ARTE AUDIOVISUAL 0.03%
#  - ECONOMIA ACTUALMENTE ANALISTA EN SISTEMAS 0.03%
#  - LICENCIATURA EN ESTADISTICA  0.03%
#  - LICENCIATURA EN MARKETINGENIERIA  0.03%
#  - LICENCIATURA EN MATEMATICA APLICADA 0.03%
#  - MARKETINGENIERIA Y ADMINISTRACION AGROINDUSTRIAL 0.03%
#  - LICENCIATURA EN ASTRONOMIA 0.03%
#  - CONTADOR PUBLICO  0.03%
#  - TECNICATURA EN WEB 0.03%
#  - MG COMUNICACION SOCIAL 0.03%
#  - LICENCIATURA EN GESTION DE RECURSOS HUMANOS 0.03%
#  - INGENIERIA ELECTRONICA Y TELECOMUNICACIONES 4TO, INGENIERIA EN SOFTWARE 5TO 0.03%
#  - PROFESORADO DE TEATRO 0.03%
#  - INGENIERIA EN REDES Y COMUNICACIONES 0.03%
#  - MG COMUNICACION ESTRATEGICA 0.03%
#  - TECNICATURA SUPERIOR EN INTELIGENCIA ARTIFICIAL Y CIENCIA DE DATOS 0.03%
#  - TRADUCCION DE INGLES 0.03%
#  - TECNICATURA EN RECURSOS HUMANOS 0.03%
#  - TRADUCTORA DE INGLES 0.03%
#  - LICENCIATURA EN TECNOLOGIA EDUCATIVA 0.03%
#  - CISCO 0.03%
#  - AUTODIDACTA 0.03%
#  - TECNICATURA UNIVERSITARIA EN MECATRONICA 0.03%
#  - LICENCIATURA EN ORGANIZACION INDUSTRIAL 0.03%
#  - LICENCIATURA EN FINANZAS 0.03%
#  - COMUNICACION AUDIOVISUAL 0.03%
#  - ARQ 0.03%
#  - CORRECTOR DE TEXTOS 0.03%
#  - TECNICATURA EN SOPORTE DE INFRAESTRUCTURA 0.03%
#  - LICENCIATURA EN RELACIONES PUBLICAS 0.03%
#  - ABOGADO  0.03%
#  - BIOTECNOLOGIA 0.03%
#  - LICENCIATURA EN DIRECCION DE NEGOCIOS 0.03%
#  - LICENCIATURAS EN CIENCIAS MATEMATICAS  0.03%
#  - COMUNICACION  0.03%
#  - CEH, CISSP, CSFPC, ETC 0.03%
#  - RELACIONES LABORALES 0.03%
#  - ADMINISTRACION  0.03%
#  - TECNICATURA EN COMUNICACION SOCIAL 0.03%
#  - CLOUD ADMINISTRATOR/ ARTES AUDIOVISUALES 0.03%
#  - CP 0.03%
#  - LICENCIATURA EN HIGIENE Y SEGURIDAD EN EL TRABAJO 0.03%
#  - DISENO Y PROGRAMACION DE SIMULADORES VIRTUALES 0.03%
#  - LOGISTICA 0.03%
#  - TECNICATURA EN DESARROLLO DE PAGINAS WEB 0.03%
#  - COMUNICACION SOCIAL, SI COMUNICACION SOCIAL 0.03%
#  - TECNICATURA SUPERIOR EN AUTOMATIZACION Y ROBOTICA 0.03%
#  - COMERCIO EXTERIOR  0.03%
#  - INGENIERIA EN SISTEMAS  0.03%
#  - DISENO DE VIDEOJUEGOS 0.03%
#  - LICENCIATURA EN COMERCIO INTERNACIONAL 0.03%
#  - NO 0.03%
#  - LICENCIATURA EN TECNOLOGIAS EDUCATIVAS 0.03%
#  - DIPLOMATURA EN CIENCIA DE DATOS 0.03%
#  - TECNICATURA SUPERIOR EN BASE DE DATOS 0.03%
#  - TECNICATURA SUPERIOR EN SOPORTE DE INFRAESTRUCTURA 0.03%
#  - TECNICATURA SUPERIOR EN REDES INFORMATICAS 0.03%
#  - TECNICATURA ELECTROMECANICA 0.03%
#  - INGENIERIA QUIMICA  0.03%
#  - BIOQUIMICA 0.03%
#  - LICENCIATURA EN ARTES VISUALES  0.03%
#  - ANALISIS DE SISTEMAS, LICENCIATURA EN PSICOLOGIA 0.03%
#  - TECNICATURA NIVERSITARIA EN DESARROLLO DE APLICACIONES INFORMATICAS 0.03%
#  - PROFESORADO DE INGLES  0.03%
#  - MAGISTER EN GESTION DE LA SEGURIDAD DE LA INFORMACION 0.03%
#  - RELACIONES DEL TRABAJO 0.03%
#  - TRADUCTOR DE INGLES 0.03%
#  - GRABACION Y PRODUCCION MUSICAL 0.03%
#  - X 0.03%
#  - LICENCIATURA EN GEOLOGIA, DOCTORADO EN CIENCIAS NATURALES 0.03%
#  - INGENIERO CIVIL 0.03%
#  - TECNICATURA EN ADMINISTRACION DE SISTEMAS Y SOFTWARE LIBRE 0.03%
#  - IMAGEN Y SONIDO 0.03%
#  - LICENCIATURA EN RECURSOS HUMANOS  0.03%
#  - TECNICATURA UNIVERSITARIO EN DESARROLLO DE SOFTWARE  0.03%
#  - ESCUELA DE EDUCACION TECNICA 0.03%
#  - TECNICATURA EN MARKETINGENIERIA Y PUBLICIDAD DIGITAL 0.03%
#  - LICENCIATURA ARTES AUDIOVISUALES 0.03%
#  - TECNICATURA SUPERIOR EN MECATRONICA 0.03%
#  - HISTOTECNOLOGIA 0.03%
#  - TECNICATURA UNIVERSITARIA EN TECNOLOGIAS DE LA INFORMACION 0.03%
#  - DISENADOR INDUSTRIAL 0.03%
#  - TECNICATURA SUPERIOR EN TECNOLOGIAS DE LA INFORMACION 0.03%
#  - MARKETINGENIERIA Y PUBLICIDAD DIGITAL 0.03%
#  - TECNICATURA CONSTRUCTOR MMO 0.03%
#  - CM 0.03%
#  - INGENERIA EN PESCA 0.03%
#  - BOOTCAMP EN PROGRAMACION WEB FULL STACK 0.03%
#  - INGENIERIA EJECUCION ELECTRONICA 0.03%
#  - INGENIERIA ADMINISTRATIVA 0.03%
#  - TECNICATURA MEDIO EN SOPORTE EN INFORMATICA 0.03%
#  - LICENCIATURA EN CIENCIAS FISCALES MENCION ADUANA Y COMERCIO  0.03%
#  - HACKING 0.03%
#  - INGENIERIA EN BIONICA 0.03%
#  - MATEMATICAS 0.03%
#  - INGENIERIA DE SISTEMAS Y COMPUTACION  0.03%
#  - FRONT END DEVELOPMENT 0.03%
#  - ANALISTA EN INFRAESTRUCTURA INFORMATICA 0.03%
#  - TECNICATURA EN DISENO WEB 0.03%
#  - ANALISTA EN INFRAESTRUCTURA 0.03%

# %% [markdown]
# 9. Printear porcentaje por identidad de género y personas con discapacidad

# %%
for row in list_data:
    row[preguntas["Me identifico"]] = row[preguntas["Me identifico"]].upper()
    
def answer_replace_str (question, str_to_replace, replacement):
    for row in list_data:
        if str_to_replace == row[preguntas[question]]:
            row[preguntas[question]] = row[preguntas[question]].replace(str_to_replace, replacement)    

answer_replace_str ("Me identifico",'VARON', 'HOMBRE CIS')
answer_replace_str ("Me identifico",'VARÓN', 'HOMBRE CIS')
answer_replace_str ("Me identifico",'MASCULINO', 'HOMBRE CIS')
answer_replace_str ("Me identifico",'VARÓN CIS', 'HOMBRE CIS')
answer_replace_str ("Me identifico",'HOMBRE', 'HOMBRE CIS')
answer_replace_str ("Me identifico",'FEMENINO', 'MUJER CIS')
answer_replace_str ("Me identifico",'MUJER', 'MUJER CIS')
answer_replace_str ("Me identifico",'VARÓN TRANS', 'HOMBRE TRANS')
answer_replace_str ("Me identifico",'NO BINARIE', 'NO BINARIO')

dic_gender = {
    "HOMBRE CIS": 0,
    "MUJER CIS": 0,
    "HOMBRE TRANS":0,
    "MUJER TRANS":0,
    "NO BINARI0":0,
    "PREFIERO NO DECIR":0,
}

for row in list_data:
    answer = row[preguntas["Me identifico"]]
    if answer in dic_gender: 
        dic_gender[answer] += ((1 / len(list_data)) * 100)
    else:     
        dic_gender[answer] = ((1 / len(list_data)) * 100)
        
gender_unexpected = 100 - (dic_gender['HOMBRE CIS'] + dic_gender['MUJER CIS'] + dic_gender['HOMBRE TRANS'] + dic_gender['MUJER TRANS']+ dic_gender['PREFIERO NO DECIR'] + dic_gender['NO BINARI0'])

print(f" {round(dic_gender['HOMBRE CIS'],2)} % de los encuestados se identifican como hombre cis")
print(f" {round(dic_gender['MUJER CIS'],2)} % de los encuestados se identifican como mujer cis")
print(f" {round(dic_gender['HOMBRE TRANS'],2)} % de los encuestados se identifican como hombre trans")
print(f" {round(dic_gender['MUJER TRANS'],2)} % de los encuestados se identifican como mujer trans")
print(f" {round(dic_gender['NO BINARI0'],2)} % de los encuestados se identifican como no binario")
print(f" {round(dic_gender['PREFIERO NO DECIR'],2)} % de los encuestados prefieren no decir")       
print(f" {round(gender_unexpected, 2)} % de las respuestas no entran en ninguna categoría de las anteriores")
# Out:
#  76.4 % de los encuestados se identifican como hombre cis
#  16.26 % de los encuestados se identifican como mujer cis
#  0.2 % de los encuestados se identifican como hombre trans
#  0.1 % de los encuestados se identifican como mujer trans
#  0 % de los encuestados se identifican como no binario
#  4.11 % de los encuestados prefieren no decir
#  2.93 % de las respuestas no entran en ninguna categoría de las anteriores

# %%
for row in list_data:
    row[preguntas["¿Tenés algún tipo de discapacidad?"]] = row[preguntas["¿Tenés algún tipo de discapacidad?"]].upper()
    
def answer_replace_str (question, str_to_replace, replacement):
    for row in list_data:
        if str_to_replace == row[preguntas[question]]:
            row[preguntas[question]] = row[preguntas[question]].replace(str_to_replace, replacement)    

answer_replace_str ("¿Tenés algún tipo de discapacidad?",'NO', 'NINGUNA')
answer_replace_str ("¿Tenés algún tipo de discapacidad?",'NINGUNO', 'NINGUNA')
answer_replace_str ("¿Tenés algún tipo de discapacidad?",'0', 'NINGUNA')
answer_replace_str ("¿Tenés algún tipo de discapacidad?",'NO APLICA', 'NINGUNA')
answer_replace_str ("¿Tenés algún tipo de discapacidad?",'NINGUNO ', 'NINGUNA')
answer_replace_str ("¿Tenés algún tipo de discapacidad?",'NINGUNA ', 'NINGUNA')

dic_disabilitie = {}

for row in list_data:
    answer = row[preguntas["¿Tenés algún tipo de discapacidad?"]].upper()
    if answer in dic_disabilitie: 
        dic_disabilitie[answer] += 1
    else:     
        dic_disabilitie[answer] = 1  

no_answer =0        
for key in dic_disabilitie:
        if key == "":
            no_answer += dic_disabilitie [key]

TotalAnswers = len(list_data) - no_answer

del(dic_disabilitie[''])

sorted_dic_disabilitie = dict(sorted(dic_disabilitie.items(), key=lambda item: item[1], reverse=True))

for key in sorted_dic_disabilitie:
    if round(sorted_dic_disabilitie[key] / TotalAnswers * 100, 2) > 0.70:
        print(f" - {key} {round(sorted_dic_disabilitie[key] / TotalAnswers * 100, 2)}%")
# Out:
#  - VISUAL 57.62%
#  - NINGUNA 13.01%
#  - AUDITIVA 4.83%
#  - MENTAL 4.83%
#  - MOTRIZ 2.23%
#  - AUDITIVA, VISUAL 1.12%
#  - VISCERAL 1.12%
#  - ADHD 0.74%
#  - EPILEPSIA 0.74%
#  - TDAH 0.74%
#  - OBESIDAD 0.74%
#  - USO ANTEOJOS 0.74%

# %% [markdown]
# 10. Salarios: calcular la mediana salarial para cada una de las siguientes categorías:
# - Salario según región
# - Salario por rol
# - Salario por experiencia
# - Salario por nivel de formación
# - Salario por género
#
# **TIP:** Podemos utilizar la biblioteca statics
#
# ```
# import statistics
#
# # unsorted list of random integers
# data1 = [2, -2, 3, 6, 9, 4, 5, -1]
#
#
# # Printing median of the
# # random data-set
# print("Median of data-set is : % s "
#         % (statistics.median(data1)))
#
# ```

# %%
dolar_conversion = (
  ('Argentina', 130.9),
  ('Bolivia', 6.86),
  ('Chile', 920.5773255),
  ('Colombia', 4445.01),
  ('Cuba', 24),
  ('Costa Rica', 671.4261825),
  ('Ecuador', 1),
  ('El Salvador', 8.75),
  ('Guatemala', 7.745829),
  ('Honduras', 24.6341828),
  ('México', 20.433),
  ('Nicaragua', 35.85),
  ('Panamá', 1),
  ('Paraguay', 6919.66395),
  ('Perú', 3.940374),
  ('Puerto Rico', 1),
  ('República Dominicana', 54.3192),
  ('Uruguay', 41.6290475),
  ('Venezuela', 5.7456)
)

#utilizo el diccionario de monedas para convertir a dolares todas las monedas

#def local_currency_to_us (row, to_convert):
    #usdollar = 0
    #for key in dolar_conversion:
        #if row[preguntas["Pais"]] == key and row[preguntas[to_convert]] != '':
            #usdollar = round(row[preguntas[to_convert]] / dolar_conversion[key], 2)
    #return(usdollar)
    

def local_currency_to_us (row, to_convert):
    usdollar = 0
    for country, dolar in dolar_conversion:
        if row[preguntas["Pais"]] == country and row[preguntas[to_convert]] != '':
            usdollar = round(float(row[preguntas[to_convert]]) / dolar, 2)
    return(usdollar)


for row in list_data:
    if row[preguntas["Pagos en dólares"]] == '':
        row[preguntas["Salario mensual o retiro NETO (en tu moneda local)"]] = local_currency_to_us (row,"Salario mensual o retiro NETO (en tu moneda local)")

# %%
import statistics
#Mediana salarial por region

list_region = list(dic_regions.keys())

regions_salaryes = []

for region in list_region: 
    
    regions_salaryes = []   
    
    for row in list_data:
        try:
            if row[preguntas["Region"]].upper() == region:
                #str(row[preguntas["Salario mensual o retiro NETO (en tu moneda local)"]]).replace(",",".")
                salary = float(row[preguntas["Salario mensual o retiro NETO (en tu moneda local)"]])
                 #Asumo que un salario mensual no va a ser menos a USD100 ni mayor a USD30.000
                if 100 < salary < 30000:
                    regions_salaryes.append(salary)
        except ValueError:
            row[preguntas["Salario mensual o retiro NETO (en tu moneda local)"]] = ''                    
            
    dic_median_regions.update({region: regions_salaryes})

for key, value in dic_median_regions.items():
    try:
        dic_median_regions[key] = float(statistics.median(dic_median_regions[key]))
    except ValueError:
        dic_median_regions[key] = 0

sorted_dic_median_regions = dict(sorted(dic_median_regions.items(), key=lambda item: item[1], reverse=True))        

for key in sorted_dic_median_regions:
    print(f" - {key} - mediana salarial US$ {round(sorted_dic_median_regions[key],2)}")
# Out:
#  - ANTIGUA GUATEMALA - mediana salarial US$ 25000.0
#  - TIJUANA - mediana salarial US$ 25000.0
#  - VILLAHERMOSA - mediana salarial US$ 12940.47
#  - LA PAZ - mediana salarial US$ 10886.3
#  - MÉRIDA - mediana salarial US$ 9500.0
#  - PACHUCA - mediana salarial US$ 6978.81
#  - SANTA TECLA - mediana salarial US$ 5900.0
#  -  - mediana salarial US$ 4905.87
#  - CACHAPOAL - mediana salarial US$ 3041.57
#  - SALINAS - mediana salarial US$ 2700.0
#  - ZAPOPAN - mediana salarial US$ 2642.78
#  - CUENCA - mediana salarial US$ 2424.0
#  - CIUDAD GUATEMALA - mediana salarial US$ 2294.78
#  - CIUDAD DE PANAMÁ - mediana salarial US$ 2104.8
#  - MÉXICO DF - mediana salarial US$ 2041.22
#  - SANTIAGO - mediana salarial US$ 2020.47
#  - CANCÚN - mediana salarial US$ 1957.62
#  - MONTEVIDEO - mediana salarial US$ 1801.63
#  - VALDIVIA - mediana salarial US$ 1779.32
#  - ECATEPEC - mediana salarial US$ 1761.86
#  - COCHABAMBA - mediana salarial US$ 1749.27
#  - GUADALAJARA - mediana salarial US$ 1590.57
#  - CHIHUAHUA - mediana salarial US$ 1566.09
#  - BARQUISIMETO - mediana salarial US$ 1500.0
#  - QUERÉTARO - mediana salarial US$ 1468.21
#  - MONTERREY - mediana salarial US$ 1468.21
#  - VERACRUZ - mediana salarial US$ 1394.81
#  - AREQUIPA - mediana salarial US$ 1392.03
#  - SAN SALVADOR - mediana salarial US$ 1360.0
#  - QUITO - mediana salarial US$ 1325.0
#  - TIERRA DEL FUEGO - mediana salarial US$ 1298.7
#  - MAIPO - mediana salarial US$ 1249.22
#  - SANTA CRUZ DE LA SIERRA - mediana salarial US$ 1239.07
#  - SALTO - mediana salarial US$ 1225.11
#  - MALDONADO - mediana salarial US$ 1213.1
#  - BIOBÍO - mediana salarial US$ 1193.75
#  - ASUNCIÓN - mediana salarial US$ 1164.8
#  - BUCARAMANGA - mediana salarial US$ 1124.86
#  - LIMA - mediana salarial US$ 1116.65
#  - TRINIDAD - mediana salarial US$ 1080.98
#  - BOGOTÁ - mediana salarial US$ 1068.62
#  - MEDELLÍN - mediana salarial US$ 1067.27
#  - LA PAMPA - mediana salarial US$ 997.92
#  - AMBATO - mediana salarial US$ 984.0
#  - CIUDAD NEZAHUALCÓYOTL - mediana salarial US$ 978.81
#  - CATAMARCA - mediana salarial US$ 962.57
#  - CIUDAD AUTÓNOMA DE BUENOS AIRES - mediana salarial US$ 954.93
#  - CUERNAVACA - mediana salarial US$ 924.74
#  - CHUBUT - mediana salarial US$ 910.55
#  - GBA - mediana salarial US$ 900.25
#  - LOJA - mediana salarial US$ 900.0
#  - MONTERÍA - mediana salarial US$ 899.89
#  - PURRAL - mediana salarial US$ 890.64
#  - SANTA FE - mediana salarial US$ 886.17
#  - SAN LUIS - mediana salarial US$ 855.62
#  - CÓRDOBA - mediana salarial US$ 855.61
#  - CARACAS - mediana salarial US$ 850.0
#  - PROVINCIA DE BUENOS AIRES - mediana salarial US$ 840.34
#  - VALPARAÍSO - mediana salarial US$ 814.71
#  - TRUJILLO - mediana salarial US$ 812.11
#  - RÍO NEGRO - mediana salarial US$ 805.96
#  - JUJUY - mediana salarial US$ 805.58
#  - TUCUMÁN - mediana salarial US$ 802.14
#  - LA RIOJA - mediana salarial US$ 788.24
#  - ENCARNACIÓN - mediana salarial US$ 780.38
#  - SAN JOSÉ - mediana salarial US$ 744.68
#  - NEUQUÉN - mediana salarial US$ 741.27
#  - PUEBLA DE ZARAGOZA - mediana salarial US$ 734.11
#  - MENDOZA - mediana salarial US$ 721.92
#  - MANIZALES - mediana salarial US$ 692.91
#  - CULIACÁN - mediana salarial US$ 685.17
#  - TUNJA - mediana salarial US$ 667.04
#  - SANTIAGO DEL ESTERO - mediana salarial US$ 656.99
#  - SANTA CRUZ - mediana salarial US$ 637.89
#  - SAN JUAN - mediana salarial US$ 636.92
#  - OAXACA DE JUÁREZ - mediana salarial US$ 636.23
#  - ENTRE RÍOS - mediana salarial US$ 630.25
#  - FORMOSA - mediana salarial US$ 611.15
#  - SALTA - mediana salarial US$ 611.15
#  - GUAYAQUIL - mediana salarial US$ 600.0
#  - MISIONES - mediana salarial US$ 584.45
#  - MORELIA - mediana salarial US$ 562.82
#  - CORRIENTES - mediana salarial US$ 551.14
#  - VICTORIA DE DURANGO - mediana salarial US$ 538.34
#  - CHACO - mediana salarial US$ 534.76
#  - SANTIAGO DE CALI - mediana salarial US$ 517.43
#  - NEIVA - mediana salarial US$ 500.0
#  - MANAGUA - mediana salarial US$ 460.25
#  - SANTO DOMINGO - mediana salarial US$ 460.24
#  - SALTILLO - mediana salarial US$ 440.46
#  - PEREIRA - mediana salarial US$ 404.95
#  - SAN CRISTÓBAL - mediana salarial US$ 350.0
#  - RIOBAMBA - mediana salarial US$ 300.0
#  - VALENCIA - mediana salarial US$ 300.0
#  - CÚCUTA - mediana salarial US$ 269.97
#  - PUNO - mediana salarial US$ 228.4
#  - PROVINCIA DE CIUDAD DE LA HABANA - mediana salarial US$ 226.79
#  - SANCTI SPÍRITUS - mediana salarial US$ 221.92
#  - TALCA - mediana salarial US$ 0
#  - FLORIDA - mediana salarial US$ 0
#  - ARAUCA - mediana salarial US$ 0
#  - SAN LORENZO - mediana salarial US$ 0
#  - BARCELONA - mediana salarial US$ 0
#  - CARTAGENA DE INDIAS - mediana salarial US$ 0
#  - HEREDIA - mediana salarial US$ 0
#  - IBAGUÉ - mediana salarial US$ 0
#  - CHINANDEGA - mediana salarial US$ 0

# %%
#Mediana salarial por experiencia
dic_median_WorkExperience={
"Junior": list(),
"Semi-Senior": list(),
"Senior": list(), 
}

for row in list_data:
    try:
        #str(row[preguntas["Salario mensual o retiro NETO (en tu moneda local)"]]).replace(",",".")
        salary = float(row[preguntas["Salario mensual o retiro NETO (en tu moneda local)"]])
        answer = float(row[preguntas["Años de experiencia"]])
        #Asumo que un salario mensual no va a ser menos a USD100 ni mayor a USD30.000 y que una persona no va a trabajar más de 70 años
        if 100 < salary < 30000 and answer < 2:
            if dic_median_WorkExperience["Junior"] == list():
                dic_median_WorkExperience["Junior"] = [salary]
            else:
                dic_median_WorkExperience["Junior"].append(salary)
        if 100 < salary < 30000 and 2 <= answer < 5:
            if dic_median_WorkExperience["Semi-Senior"] == list():
                dic_median_WorkExperience["Semi-Senior"] = [salary]
            else:
                dic_median_WorkExperience["Semi-Senior"].append(salary)
        if 100 < salary < 30000 and 5 <= answer < 71:
            if dic_median_WorkExperience["Senior"] == list():
                dic_median_WorkExperience["Senior"] = [salary]
            else:
                dic_median_WorkExperience["Senior"].append(salary)
    except ValueError:
        row[preguntas["Salario mensual o retiro NETO (en tu moneda local)"]] = ''

for key, value in dic_median_WorkExperience.items():
    try:
        dic_median_WorkExperience[key] = float(statistics.median(dic_median_WorkExperience[key]))
    except ValueError:
        dic_median_WorkExperience[key] = 0
        
for key in dic_WorkExperience:
    print(f" - {key} - mediana salarial US$ {dic_median_WorkExperience[key]}")
# Out:
#  - Junior - mediana salarial US$ 546.22
#  - Semi-Senior - mediana salarial US$ 840.34
#  - Senior - mediana salarial US$ 1088.13

# %%
#Mediana salarial por rol
#Para este análisis voy a tomar los roles más representativos de los encuentados ya que hay mucha variedad
dic_role={}
    
for row in list_data:
    answer = row[preguntas["Trabajo de"]].upper()
    if answer in dic_role: 
        dic_role[answer] += 1
    else:     
        dic_role[answer] = 1

no_answer =0        
for key in dic_role:
        if key == "":
            no_answer += dic_role [key]

TotalAnswers = len(list_data) - no_answer

sorted_dic_role = dict(sorted(dic_role.items(), key=lambda item: item[1], reverse=True))

list_role = list()
for key in sorted_dic_role:
    if sorted_dic_role[key] / TotalAnswers * 100 > 1:
        list_role.append(key)
#print(list_role)    

dic_median_role = {}

role_salaryes = []

for role in list_role: 
    
    role_salaryes = []   
    
    for row in list_data:
        try:
            if row[preguntas["Trabajo de"]].upper() == role:
                str(row[preguntas["Salario mensual o retiro NETO (en tu moneda local)"]]).replace(",",".")
                salary = float(row[preguntas["Salario mensual o retiro NETO (en tu moneda local)"]])
                 #Asumo que un salario mensual no va a ser menor a USD100 ni mayor a USD30.000
                if 100 < salary < 30000:
                    role_salaryes.append(salary)
        except ValueError:
            row[preguntas["Salario mensual o retiro NETO (en tu moneda local)"]] = ''                    
            
    dic_median_role.update({role: role_salaryes})

for key, value in dic_median_role.items():
    try:
        dic_median_role[key] = float(statistics.median(dic_median_role[key]))
    except ValueError:
        dic_median_role[key] = 0

sorted_dic_median_role = dict(sorted(dic_median_role.items(), key=lambda item: item[1], reverse=True))        

for key in sorted_dic_median_role:
    print(f" - {key} - mediana salarial US$ {round(sorted_dic_median_role[key],2)}")
# Out:
#  - MANAGER / DIRECTOR - mediana salarial US$ 1527.88
#  - ARCHITECT - mediana salarial US$ 1327.11
#  - PRODUCT MANAGER - mediana salarial US$ 1237.59
#  - TECHNICAL LEADER - mediana salarial US$ 1236.77
#  - PROJECT MANAGER - mediana salarial US$ 1184.11
#  - DATA SCIENTIST - mediana salarial US$ 1008.4
#  - INFOSEC - mediana salarial US$ 991.59
#  - DATA ENGINEER - mediana salarial US$ 958.75
#  - SYSADMIN / DEVOPS / SRE - mediana salarial US$ 951.11
#  - BUSINESS ANALYST - mediana salarial US$ 916.73
#  - UX - mediana salarial US$ 916.73
#  - DEVELOPER - mediana salarial US$ 878.53
#  - CONSULTANT - mediana salarial US$ 840.34
#  - BI ANALYST / DATA ANALYST - mediana salarial US$ 802.14
#  - NETWORKING - mediana salarial US$ 786.86
#  - QA / TESTER - mediana salarial US$ 771.58
#  - RECRUITER / HR - mediana salarial US$ 687.55
#  - HELPDESK - mediana salarial US$ 488.92

# %%
import statistics
#Mediana salarial por nivel de formación

set_educational_level = set()
for row in list_data:
    educational_level = row[preguntas["Nivel de estudios alcanzado"]].upper()
    set_educational_level.add(educational_level)

list_educational_level = list(set_educational_level)

educational_level_salaryes = []

for educational_level in list_educational_level: 
    
    educational_level_salaryes = []   
    
    for row in list_data:
        try:
            if row[preguntas["Nivel de estudios alcanzado"]].upper() == educational_level:
                str(row[preguntas["Salario mensual o retiro NETO (en tu moneda local)"]]).replace(",",".")
                salary = float(row[preguntas["Salario mensual o retiro NETO (en tu moneda local)"]])
                #Asumo que un salario mensual no va a ser menor a USD100 ni mayor a USD30.000
                if 100 < salary < 30000:
                    educational_level_salaryes.append(salary)
        except ValueError:
            row[preguntas["Salario mensual o retiro NETO (en tu moneda local)"]] = ''                    
            
    dic_median_educational_level.update({educational_level: educational_level_salaryes})

for key, value in dic_median_educational_level.items():
    try:
        dic_median_educational_level[key] = float(statistics.median(dic_median_educational_level[key]))
    except ValueError:
        dic_median_educational_level[key] = 0

sorted_dic_median_educational_level = dict(sorted(dic_median_educational_level.items(), key=lambda item: item[1], reverse=True))        
del(sorted_dic_median_educational_level[''])
for key in sorted_dic_median_educational_level:
    print(f" - {key} - mediana salarial US$ {round(sorted_dic_median_educational_level[key],2)}")
# Out:
#  - POSDOCTORADO - mediana salarial US$ 1336.89
#  - PRIMARIO - mediana salarial US$ 1222.31
#  - DOCTORADO - mediana salarial US$ 1214.67
#  - POSGRADO - mediana salarial US$ 1122.99
#  - UNIVERSITARIO - mediana salarial US$ 932.01
#  - TERCIARIO - mediana salarial US$ 840.34
#  - SECUNDARIO - mediana salarial US$ 802.14

# %%
import statistics
#Mediana salarial por genero

dic_median_gender = {
    "HOMBRE CIS":list(),
    "MUJER CIS": list(),
    "HOMBRE TRANS":list(),
    "MUJER TRANS":list(),
    "NO BINARI0":list(),
    "PREFIERO NO DECIR":list(),
}

list_gender = list(dic_median_gender.keys())

gender_salaryes = []

for gender in list_gender: 
    
    gender_salaryes = []   
    
    for row in list_data:
        try:
            if row[preguntas["Me identifico"]].upper() == gender:
                str(row[preguntas["Salario mensual o retiro NETO (en tu moneda local)"]]).replace(",",".")
                salary = float(row[preguntas["Salario mensual o retiro NETO (en tu moneda local)"]])
                #Asumo que un salario mensual no va a ser menor a USD100 ni mayor a USD30.000
                if 100 < salary < 30000:
                    gender_salaryes.append(salary)
        except ValueError:
            row[preguntas["Salario mensual o retiro NETO (en tu moneda local)"]] = ''                    
            
    dic_median_gender.update({gender: gender_salaryes})

for key, value in dic_median_gender.items():
    try:
        dic_median_gender[key] = float(statistics.median(dic_median_gender[key]))
    except ValueError:
        dic_median_gender[key] = 0

sorted_dic_median_gender = dict(sorted(dic_median_gender.items(), key=lambda item: item[1], reverse=True))        

for key in sorted_dic_median_gender:
    print(f" - {key} - mediana salarial US$ {round(sorted_dic_median_gender[key],2)}")
# Out:
#  - HOMBRE TRANS - mediana salarial US$ 1214.67
#  - HOMBRE CIS - mediana salarial US$ 951.11
#  - PREFIERO NO DECIR - mediana salarial US$ 950.0
#  - MUJER CIS - mediana salarial US$ 787.55
#  - MUJER TRANS - mediana salarial US$ 634.07
#  - NO BINARI0 - mediana salarial US$ 0

# %% [markdown]
# 11. En base a los resultados obtenidos confeccionar conclusiones respecto a:
#
# - Rol vs sueldos
# - Nivel de educación alcanzada vs sueldos
# - Género vs sueldos

# %% [markdown]
# Conclusiones debajo de cada gráfica

# %% [markdown]
# 12. Generar gráficos de barra para mostrar los resultados mencionados anteriormente usando strings, ej:
#
# ```
# developer | -----------------------------------------------
# sysadmin  | ---------------------------
# QA        | ------------------
#           | ..................5%.......10%...............40%
# ```

# %%
#Para realización de gráficos de barra
import matplotlib.pyplot as plt

# %%
D = {u'MANAGER / DIRECTOR':1527.88, u'ARCHITECT': 1327.11, u'PRODUCT MANAGER ':1237.59, u'DATA SCIENTIST ':1008.4, u'BUSINESS ANALYST ':916.73, u'QA / TESTER ':771.58, u'RECRUITER / HR':687.55, u'HELPDESK':488.92}

plt.bar(range(len(D)), list(D.values()), align='center')
plt.xticks(range(len(D)), list(D.keys()))
plt.title("Mediana Salarial por Nivel de educación alcanzada")
plt.ylabel("Mediana salarial USD")
plt.show()

# %% [markdown]
# Rol vs sueldos:
#
# -Los roles de Director, Manager, Leader son los que tienen una mediana salarial mayor, también los que implican toma de desiciones, cómo Product Manager o Project Manager.
#
# -Los roles que implican manejo y análisis de datos cómo InfoSec, Data Scientist o Data Engineer son los que siguen con una mediana salarial mayor.
#
# -La ultima franja entre los mejores pagos son los especialistas en UX, Developers y Business Analyst.
#
# -los roles menos remunerados, parecen ser roles para empleados con menos experimentados, cómo QA y Tester o de actividades que no implican el uso de la programación, como Recruiter, HR o Helpdesk.

# %%
D = {u'POSDOCTORADO':1336.89, u'PRIMARIO': 1222.31, u'DOCTORADO ':1214.67, u'POSGRADO ':1122.99, u'UNIVERSITARIO ':932.01, u'TERCIARIO ':840.34, u'SECUNDARIO  ':802.14}

plt.bar(range(len(D)), list(D.values()), align='center')
plt.xticks(range(len(D)), list(D.keys()))
plt.title("Mediana Salarial por Nivel de educación alcanzada")
plt.ylabel("Mediana salarial USD")
plt.show()

# %% [markdown]
# Nivel de educación alcanzada vs sueldos:
#
# -Si bien la mediana salarial del nivel de estudio posdoctorado es la mayor, la cantidad de personas con este nivel encuestados no es representativo, 0.1% aprox del total.
#
# -Si bien el nivel educativo influye en la mediana salarial, la variación entre nivel universitario y terciario no es tanta, 10% aprox, por lo que podemos concluir que tener un título universitario no es determinante para el sueldo.
#
# -Si bien el nivel primario dio un resultado mayor que universitario, la cantidad de personas con este nivel encuestados no es representativo, 0.03% aprox del total.

# %%
D = {u'HOMBRE TRANS':1214.67, u'HOMBRE CIS': 951.11, u'PREFIERO NO DECIR':950.0, u'MUJER CIS':787.55, u'MUJER TRANS':634.07}

plt.bar(range(len(D)), list(D.values()), align='center')
plt.xticks(range(len(D)), list(D.keys()))
plt.title("Mediana Salarial por genero")
plt.xlabel("genero")
plt.ylabel("Mediana salarial USD")
plt.show()

# %% [markdown]
# Género vs sueldos:
#
# -Si bien la mediana salarial del hombre trans es la mayor, la cantidad de hombres trans encuestados no es representativo, 0.2% del total de encuentados.
#
# -las mujeres cis ganan aproximadamente 20% menos que los hombres cis. También son minoría en esta industria, representando un 16.26% del total.
#
# -Los resultados obtenidos sobre personas trans y no binario se obtuvieron sobre muy pocos casos y no son concluyentes.

# %% [markdown]
# Resultados de la encuesta: https://sueldos.openqube.io/encuesta-sueldos-2021.02/
